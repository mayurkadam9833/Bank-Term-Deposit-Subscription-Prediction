# %%
# import required packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# loading dataset
data=pd.read_csv("bank_full.csv",sep=";")

# %%
# first five rows of dataset
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Total records and features in dataset
print("Total records in dataset:",data.shape[0])
print("Total features in dataset:",data.shape[1])
# Out:
# Total records in dataset: 45211
# Total features in dataset: 17

# %%
# dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
unique_col={col:data[col].unique() for col in data.columns}
unique_col
# Out:
# {'age': array([58, 44, 33, 47, 35, 28, 42, 43, 41, 29, 53, 57, 51, 45, 60, 56, 32,
#         25, 40, 39, 52, 46, 36, 49, 59, 37, 50, 54, 55, 48, 24, 38, 31, 30,
#         27, 34, 23, 26, 61, 22, 21, 20, 66, 62, 83, 75, 67, 70, 65, 68, 64,
#         69, 72, 71, 19, 76, 85, 63, 90, 82, 73, 74, 78, 80, 94, 79, 77, 86,
#         95, 81, 18, 89, 84, 87, 92, 93, 88], dtype=int64),
#  'job': array(['management', 'technician', 'entrepreneur', 'blue-collar',
#         'unknown', 'retired', 'admin.', 'services', 'self-employed',
#         'unemployed', 'housemaid', 'student'], dtype=object),
#  'marital': array(['married', 'single', 'divorced'], dtype=object),
#  'education': array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object),
#  'default': array(['no', 'yes'], dtype=object),
#  'balance': array([ 2143,    29,     2, ...,  8205, 14204, 16353], dtype=int64),
#  'housing': array(['yes', 'no'], dtype=object),
#  'loan': array(['no', 'yes'], dtype=object),
# ...

# %%
plt.figure(figsize=(15,15))
plt.subplot(4,3,1)
sns.histplot(data["age"],kde=True,bins=20)
plt.subplot(4,3,2)
sns.histplot(data["balance"],kde=True,bins=50)
plt.subplot(4,3,3)
sns.histplot(data["day"],kde=True,bins=10)
plt.subplot(4,3,4)
sns.histplot(data["duration"],kde=True,bins=50)
plt.subplot(4,3,5)
sns.histplot(data["campaign"],kde=True,bins=20)
plt.subplot(4,3,6)
sns.histplot(data["pdays"],kde=True,bins=25)
plt.subplot(4,3,7)
sns.histplot(data["previous"],kde=True,bins=50)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
plt.figure(figsize=(25,25))
plt.subplot(5,2,1)
data["job"].value_counts().plot(kind="bar")
plt.xticks(rotation=25)
plt.subplot(5,2,2)
data["marital"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,3)
data["education"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,4)
data["default"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,5)
data["housing"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,6)
data["loan"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,7)
data["contact"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,8)
data["month"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,9)
data["poutcome"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.subplot(5,2,10)
data["y"].value_counts().plot(kind="bar")
plt.xticks(rotation=0)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
data[data.select_dtypes(include=["object"]).columns]=data[data.select_dtypes(include=["object"]).columns].apply(encode.fit_transform)

# %%
corr=data.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr,cmap="coolwarm",annot=True)
plt.show()

# %%
data.skew().sort_values()
# Out:
# poutcome     -1.973561
# month        -0.480272
# housing      -0.224766
# marital      -0.102826
# day           0.093079
# education     0.197275
# job           0.261755
# age           0.684818
# contact       0.769381
# loan          1.852617
# y             2.383480
# pdays         2.615715
# duration      3.144318
# campaign      4.898650
# default       7.245375
# balance       8.360308
# previous     41.846454
# dtype: float64

# %%
x=data.drop(["y"],axis=1)
y=data["y"]

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
train_y.value_counts()
# Out:
# y
# 0    31970
# 1     4198
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sampling=SMOTE()
train_x,train_y=sampling.fit_resample(train_x,train_y)

# %%
train_y.value_counts()
# Out:
# y
# 0    31970
# 1    31970
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

scale.fit(train_x)

scale_train_x=scale.transform(train_x)
scale_test_x=scale.transform(test_x)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score

# %%
def get_metrics(actual,predicted):
    acc=accuracy_score(actual,predicted)
    cf=confusion_matrix(actual,predicted)
    pr=precision_score(actual,predicted)
    rc=recall_score(actual,predicted)
    f1=f1_score(actual,predicted)
    roc=roc_auc_score(actual,predicted)
    return acc,cf,pr,rc,f1,roc

# %%
models={
    "DecisionTreeClassifier":DecisionTreeClassifier(),
    "RandomForestClassifier":RandomForestClassifier(),
    "AdaBoostClassifier":AdaBoostClassifier(),
    "GradientBoostingClassifier":GradientBoostingClassifier(),
    "XGBClassifier":XGBClassifier()
}

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(scale_train_x,train_y)

    train_pred=model.predict(scale_train_x)
    test_pred=model.predict(scale_test_x)

    train_acc,train_cf,train_pr,train_rc,train_f1,train_roc=get_metrics(train_y,train_pred)
    test_acc,test_cf,test_pr,test_rc,test_f1,test_roc=get_metrics(test_y,test_pred)

    print(list(models.keys())[i])
    print("---------------------------------------------------")
    print("Training dataset:")
    print("accuracy score:",train_acc)
    print("confusion matrix:\n",train_cf)
    print("precision score:",train_pr)
    print("recall score:",train_rc)
    print("f1 score:",train_f1)
    print("roc auc score:",train_roc)
    print("---------------------------------------------------")
    print("Testing dataset:")
    print("accuracy score:",test_acc)
    print("confusion matrix:\n",test_cf)
    print("precision score:",test_pr)
    print("recall score:",test_rc)
    print("f1 score:",test_f1)
    print("roc auc score:",test_roc)
    print("="*70,"\n")
# Out:
# DecisionTreeClassifier
# ---------------------------------------------------
# Training dataset:
# accuracy score: 1.0
# confusion matrix:
#  [[31970     0]
#  [    0 31970]]
# precision score: 1.0
# recall score: 1.0
# f1 score: 1.0
# roc auc score: 1.0
# ---------------------------------------------------
# Testing dataset:
# accuracy score: 0.8477275240517528
# confusion matrix:
#  [[7029  923]
#  [ 454  637]]
# precision score: 0.4083333333333333
# recall score: 0.5838680109990834
# f1 score: 0.4805733685401735
# roc auc score: 0.7338982912138273
# ...
#
# RandomForestClassifier
# ---------------------------------------------------
# Training dataset:
# accuracy score: 1.0
# confusion matrix:
#  [[31970     0]
#  [    0 31970]]
# precision score: 1.0
# recall score: 1.0
# f1 score: 1.0
# roc auc score: 1.0
# ---------------------------------------------------
# Testing dataset:
# accuracy score: 0.8781377861329205
# confusion matrix:
#  [[7222  730]
#  [ 372  719]]
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
cv=StratifiedKFold()
gb=GradientBoostingClassifier()

n_estimators_gb=[int(x) for x in np.linspace(start=50,stop=100,num=5)]
max_depth_gb=[int(x) for x in np.linspace(start=3,stop=30,num=2)]
learning_rate_gb=[0.1,0.01,0.02,0.2]
min_samples_split_gb=[2,3,4,5,6]
min_samples_leaf_gb=[1,2,3]

params_gb=dict(n_estimators=n_estimators_gb,max_depth=max_depth_gb,learning_rate=learning_rate_gb,min_samples_split=min_samples_split_gb,min_samples_leaf=min_samples_leaf_gb)
gb_tun=RandomizedSearchCV(estimator=gb,param_distributions=params_gb,n_iter=10,n_jobs=-1,scoring="accuracy",cv=cv,verbose=1)

gb_tun.fit(scale_train_x,train_y)

train_pred_gb=gb_tun.predict(scale_train_x)
test_pred_gb=gb_tun.predict(scale_test_x)

train_acc,train_cf,train_pr,train_rc,train_f1,train_roc=get_metrics(train_y,train_pred_gb)
test_acc,test_cf,test_pr,test_rc,test_f1,test_roc=get_metrics(test_y,test_pred_gb)


print("hyperparameter tunning GradientBoostingClassifier")
print("---------------------------------------------------")
print("Training dataset:")
print("accuracy score:",train_acc)
print("confusion matrix:\n",train_cf)
print("precision score:",train_pr)
print("recall score:",train_rc)
print("f1 score:",train_f1)
print("roc auc score:",train_roc)
print("---------------------------------------------------")
print("Testing dataset:")
print("accuracy score:",test_acc)
print("confusion matrix:\n",test_cf)
print("precision score:",test_pr)
print("recall score:",test_rc)
print("f1 score:",test_f1)
print("roc auc score:",test_roc)
print("="*70,"\n")

print(gb_tun.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# hyperparameter tunning GradientBoostingClassifier
# ---------------------------------------------------
# Training dataset:
# accuracy score: 1.0
# confusion matrix:
#  [[31970     0]
#  [    0 31970]]
# precision score: 1.0
# recall score: 1.0
# f1 score: 1.0
# roc auc score: 1.0
# ---------------------------------------------------
# Testing dataset:
# accuracy score: 0.8824505142098861
# confusion matrix:
#  [[7283  669]
#  [ 394  697]]
# precision score: 0.5102489019033675
# recall score: 0.6388634280476627
# f1 score: 0.5673585673585674
# roc auc score: 0.7773668246878154
# ...
#
# {'n_estimators': 100, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_depth': 30, 'learning_rate': 0.2}
